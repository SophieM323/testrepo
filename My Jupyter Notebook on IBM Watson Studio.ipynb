# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sophia Hussein Mwinyi**
#
#
# Research & Data Scientist

# %% [markdown]
# *I am interested in Data Science because it is a field that is widely applicable in different sectors.*
#
# *It is also an upcoming field in this modern age of technology where a significant amount of data is generated and experts in analysing the large amounts of data are scarce.*
#
# *It is a field which is fulfilling as in analysing and telling a story can bring about a significant impact in decision making, policy making as well as performance of business processes, save lives in medicine and healthcare inductry and many other benefits.*

# %% [markdown]
# ### The code is supposed to display the output of the square root of 10000000

# %%
import math as m

m.sqrt(10000000)
# Out:
# 3162.2776601683795

# %% [markdown]
# This table includes data collected from the below listed regions:
# 1. Kagera
# 2. Tanga
# 3. Mara
#
# ~~Don't mind this list, just look at the table~~
#
# ![image.png](attachment:image.png)
